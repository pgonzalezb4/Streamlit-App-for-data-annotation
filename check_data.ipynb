# %%
import pandas as pd

# %%
dataset = pd.read_parquet('master_news_scraped.parquet.gzip')

# %%
dataset['country'] = dataset['country'].apply(lambda x : 'Multiple countries (euronews)' if x == 'Multiple (euronews)' else x)

# %%
dataset.to_parquet('master_news_scraped.parquet.gzip', compression='gzip', index=False)

# %%
dataset
# Out:
#                                                      url
# 0      https://cincodias.elpais.com/companias/2023-06...  \
# 1      https://www.lemonde.fr/politique/article/2023/...
# 2      https://www.faz.net/suche/selbstbestimmungsges...
# 3      https://es.euronews.com/cultura/2023/05/11/son...
# 4      http://www.corriere.it/economia/lavoro/23_giug...
# ...                                                  ...
# 11927  https://www.lemonde.fr/politique/article/2023/...
# 11928  https://elpais.com/espana/catalunya/2023-05-16...
# 11929  https://www.repubblica.it/politica/2023/04/19/...
# 11930  https://elpais.com/espana/elecciones-autonomic...
# 11931  https://elpais.com/espana/2023-05-25/la-forens...
#
#                                                    title
# 0      Una multinacional invertirá más de 4.500 millo...  \
# 1      Réforme des retraites : « Emmanuel Macron devi...
# 2                                      Zurück zur Natur?
# ...
