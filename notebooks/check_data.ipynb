# %%
import pandas as pd

# %%
df = pd.read_parquet('raw_labeled_data_20231127_14_50_24.parquet.gzip')

# %%
df
# Out:
#                          article_id  \
# 0  20008eb861d22b9760118e9cb9fd9253
# 1  cd8bb7485063a1b057cfb1f59305de07
# 2  b2ab4bce65ebc62136eeb91e92790b41
# 3  1150e86110bfade0d4bcdf8c961e5c0a
# 4  927cc0b37dfc6834941649d3a9acc844
# 5  bae71c085196d084537b3fe79b20e95d
#
#                                                 link  \
# 0  https://timesofmalta.com/articles/view/announc...
# 1  https://www.mopo.de/hamburg/wochenende-in-hamb...
# 2  https://www.lepoint.fr/politique/clement-beaun...
# 3  https://www.elperiodicoextremadura.com/feria-d...
# 4  http://www.metro.cz/revirni-pohodova-padesatka...
# 5  https://www.focus.de/experts/benedikt-boehm-be...
#
#                     factor(s)                   sentiment  \
# 0  Not related to Rule of Law  Not related to Rule of Law
# 1  Not related to Rule of Law  Not related to Rule of Law
# 2               ['No Pillar']                     Neutral
# 3  Not related to Rule of Law  Not related to Rule of Law
# ...
